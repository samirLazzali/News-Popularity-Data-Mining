# %% [markdown]
# # Data Mining

# %% [markdown]
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('OnlineNewsPopularity_new.csv').iloc[:,1:]
# Out:
# /Users/titigmr/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df[df.titre == "The Bad News"]
# Out:
#                                                      url   timedelta  \
# 4669         http://mashable.com/2013/04/01/easy-pranks/       647.0
# 14685  http://mashable.com/2013/10/16/young-adult-boo...       448.0
# 15228       http://mashable.com/2013/10/28/creepypastas/       437.0
# 16925  http://mashable.com/2013/12/03/build-mobile-apps/       401.0
# 18583  http://mashable.com/2014/01/09/best-gaming-lap...       364.0
# 21340    http://mashable.com/2014/03/04/free-audiobooks/       310.0
# 21429  http://mashable.com/2014/03/05/sun-stars-space...       309.0
# 33262        http://mashable.com/2014/04/21/how-to-sign/       262.0
# 33990  http://mashable.com/2014/05/02/websites-to-was...       250.0
# 36108  http://mashable.com/2014/06/10/mobile-apps-org...       212.0
# 36502   http://mashable.com/2014/06/16/text-from-laptop/       206.0
# 37327  http://mashable.com/2014/06/28/phone-screen-sc...       193.0
# 37562  http://mashable.com/2014/07/02/how-delete-face...       190.0
# ...

# %%
df.isnull().sum()
# Out:
# url                                 0
#  timedelta                          0
#  n_tokens_title                     2
#  n_tokens_content                   2
#  n_unique_tokens                    2
#                                  ...
#  abs_title_sentiment_polarity       2
#  shares                             2
# content                           188
# titre                            9512
# len_img                          9577
# Length: 64, dtype: int64

# %%
df[df.content.isnull()]
# Out:
#                                                      url   timedelta  \
# 4669         http://mashable.com/2013/04/01/easy-pranks/       647.0
# 4709   http://mashable.com/2013/04/01/troll-appreciat...       647.0
# 14685  http://mashable.com/2013/10/16/young-adult-boo...       448.0
# 15228       http://mashable.com/2013/10/28/creepypastas/       437.0
# 16623  http://mashable.com/2013/11/25/kiwi-gardner-ba...       409.0
# ...                                                  ...         ...
# 48705  http://mashable.com/2014/12/20/motorcycles-ski...        16.0
# 48751  http://mashable.com/2014/12/22/best-content-de...        15.0
# 48792       http://mashable.com/2014/12/22/news-of-2014/        14.0
# 48880  http://mashable.com/2014/12/24/1968-daddys-gon...        12.0
# 48897  http://mashable.com/2014/12/24/havana-before-c...        11.0
#
#         n_tokens_title   n_tokens_content   n_unique_tokens  \
# 4669              10.0              439.0          0.591549
# ...
